# %% [markdown]
# ## 1. IMPORTING

# %%
import tensorflow as tf

# %% [markdown]
# ## 2. CONVERSION

# %%
import tensorflow as tf

def convert_to_tflite(keras_model_path, tflite_output_path):
    model = tf.keras.models.load_model(keras_model_path)
    
    converter = tf.lite.TFLiteConverter.from_keras_model(model)
    converter.optimizations = [tf.lite.Optimize.DEFAULT]
    tflite_model = converter.convert()  

    tflite_output_path = 'Models/tflite_conversion/best_model.tflite'
    
    with open(tflite_output_path, "wb") as f:
        f.write(tflite_model)
    
    print(f"Model converted to: {tflite_output_path}")
    return tflite_output_path

# Usage
convert_to_tflite(
    keras_model_path='Models/EfficientNetB3/efficientnetb3_model.keras',
    tflite_output_path='Models/tflite_conversion/best_model.tflite'
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       2     keras_model_path = 'Models/EfficientNetB3/efficientnetb3_model.keras'
#       3     model = tf.keras.models.load_model(keras_model_path)
# ----> 4 converter = tf.lite.TFLiteConverter.from_keras_model(model)
#       5 converter.optimizations = [tf.lite.Optimize.DEFAULT]
#       7 tflite_model = converter.convert()
#
# NameError: name 'model' is not defined

# %% [markdown]
# ## 3. OUTPUT
