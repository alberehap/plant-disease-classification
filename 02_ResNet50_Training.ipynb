# %%
# 1. IMPORTING
import os
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

# %%
# 2. LOAD DATASET
base_dir = r"data\processed"
train_dir = os.path.join(base_dir, "train")
val_dir   = os.path.join(base_dir, "val")
test_dir  = os.path.join(base_dir, "test")

img_size = (224, 224)
batch_size = 32

train_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
val_datagen   = ImageDataGenerator(preprocessing_function=preprocess_input)
test_datagen  = ImageDataGenerator(preprocessing_function=preprocess_input)

train_gen = train_datagen.flow_from_directory(
    train_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode="categorical"
)

val_gen = val_datagen.flow_from_directory(
    val_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode="categorical"
)

test_gen = test_datagen.flow_from_directory(
    test_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode="categorical",
    shuffle=False
)

num_classes = train_gen.num_classes
print("Number of classes:", num_classes)
print("Class names:", train_gen.class_indices)
# Out:
# Found 507 images belonging to 9 classes.
# Found 142 images belonging to 9 classes.
# Found 82 images belonging to 9 classes.
# Number of classes: 9
# Class names: {'Pepper__bell___Bacterial_spot': 0, 'Pepper__bell___healthy': 1, 'Potato___Early_blight': 2, 'Potato___Late_blight': 3, 'Potato___healthy': 4, 'Tomato__Target_Spot': 5, 'Tomato__Tomato_YellowLeaf__Curl_Virus': 6, 'Tomato__Tomato_mosaic_virus': 7, 'Tomato_healthy': 8}

# %%
# 3. BUILDING MODEL
base_model = ResNet50(
    include_top=False,
    weights="imagenet",
    input_shape=(224, 224, 3)
)

base_model.trainable = False

model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(256, activation="relu"),
    layers.Dropout(0.5),
    layers.Dense(num_classes, activation="softmax")
])

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ resnet50 (Functional)           │ (None, 7, 7, 2048)     │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       524,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 9)              │         2,313 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 24,114,569 (91.99 MB)
#  Trainable params: 526,857 (2.01 MB)
#  Non-trainable params: 23,587,712 (89.98 MB)

# %%
# 4. TRAIN
resnet_dir = os.path.join('Models', 'ResNet50')
os.makedirs(resnet_dir, exist_ok=True)

checkpoint = ModelCheckpoint(
    os.path.join(resnet_dir, 'resnet50_phase1_best.keras'),
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=1
)

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.3,
    patience=3,
    verbose=1
)

history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=15,
    callbacks=[checkpoint, early_stop, reduce_lr]
)
# Out:
# Epoch 1/15
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 726ms/step - accuracy: 0.3505 - loss: 1.9948
# Epoch 1: val_accuracy improved from None to 0.88028, saving model to Models\ResNet50\resnet50_phase1_best.keras
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 0.5187 - loss: 1.4666 - val_accuracy: 0.8803 - val_loss: 0.3911 - learning_rate: 0.0010
# Epoch 2/15
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 636ms/step - accuracy: 0.8324 - loss: 0.5139
# Epoch 2: val_accuracy improved from 0.88028 to 0.93662, saving model to Models\ResNet50\resnet50_phase1_best.keras
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 14s 894ms/step - accuracy: 0.8501 - loss: 0.4512 - val_accuracy: 0.9366 - val_loss: 0.1972 - learning_rate: 0.0010
# Epoch 3/15
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 663ms/step - accuracy: 0.8617 - loss: 0.3722
# Epoch 3: val_accuracy improved from 0.93662 to 0.96479, saving model to Models\ResNet50\resnet50_phase1_best.keras
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 15s 934ms/step - accuracy: 0.9034 - loss: 0.3052 - val_accuracy: 0.9648 - val_loss: 0.1539 - learning_rate: 0.0010
# Epoch 4/15
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 695ms/step - accuracy: 0.9379 - loss: 0.1877
# Epoch 4: val_accuracy improved from 0.96479 to 0.97887, saving model to Models\ResNet50\resnet50_phase1_best.keras
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 21s 972ms/step - accuracy: 0.9428 - loss: 0.1724 - val_accuracy: 0.9789 - val_loss: 0.0930 - learning_rate: 0.0010
# Epoch 5/15
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 694ms/step - accuracy: 0.9766 - loss: 0.1323
# Epoch 5: val_accuracy did not improve from 0.97887
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 15s 915ms/step - accuracy: 0.9645 - loss: 0.1360 - val_accuracy: 0.9789 - val_loss: 0.0708 - learning_rate: 0.0010
# Epoch 6/15
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 691ms/step - accuracy: 0.9619 - loss: 0.0995
# Epoch 6: val_accuracy did not improve from 0.97887
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 14s 905ms/step - accuracy: 0.9645 - loss: 0.1060 - val_accuracy: 0.9789 - val_loss: 0.0745 - learning_rate: 0.0010
# Epoch 7/15
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 689ms/step - accuracy: 0.9827 - loss: 0.0718
# Epoch 7: val_accuracy improved from 0.97887 to 0.98592, saving model to Models\ResNet50\resnet50_phase1_best.keras
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 15s 954ms/step - accuracy: 0.9763 - loss: 0.0849 - val_accuracy: 0.9859 - val_loss: 0.0641 - learning_rate: 0.0010
# Epoch 8/15
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 688ms/step - accuracy: 0.9928 - loss: 0.0580
# Epoch 8: val_accuracy improved from 0.98592 to 0.99296, saving model to Models\ResNet50\resnet50_phase1_best.keras
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 15s 965ms/step - accuracy: 0.9882 - loss: 0.0605 - val_accuracy: 0.9930 - val_loss: 0.0577 - learning_rate: 0.0010
# Epoch 9/15
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 682ms/step - accuracy: 0.9893 - loss: 0.0635
# Epoch 9: val_accuracy did not improve from 0.99296
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 14s 878ms/step - accuracy: 0.9862 - loss: 0.0672 - val_accuracy: 0.9789 - val_loss: 0.0675 - learning_rate: 0.0010
# Epoch 10/15
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 634ms/step - accuracy: 0.9919 - loss: 0.0528
# Epoch 10: val_accuracy did not improve from 0.99296
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 13s 834ms/step - accuracy: 0.9941 - loss: 0.0490 - val_accuracy: 0.9859 - val_loss: 0.0556 - learning_rate: 0.0010
# Epoch 11/15
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 633ms/step - accuracy: 0.9986 - loss: 0.0377
# Epoch 11: val_accuracy did not improve from 0.99296
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 13s 828ms/step - accuracy: 0.9961 - loss: 0.0407 - val_accuracy: 0.9930 - val_loss: 0.0439 - learning_rate: 0.0010
# Epoch 12/15
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 637ms/step - accuracy: 0.9963 - loss: 0.0269
# Epoch 12: val_accuracy did not improve from 0.99296
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 13s 838ms/step - accuracy: 0.9961 - loss: 0.0306 - val_accuracy: 0.9930 - val_loss: 0.0402 - learning_rate: 0.0010
# Epoch 13/15
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 664ms/step - accuracy: 0.9947 - loss: 0.0367
# Epoch 13: val_accuracy did not improve from 0.99296
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 14s 862ms/step - accuracy: 0.9961 - loss: 0.0393 - val_accuracy: 0.9930 - val_loss: 0.0350 - learning_rate: 0.0010
# Epoch 14/15
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 650ms/step - accuracy: 0.9944 - loss: 0.0249
# Epoch 14: val_accuracy did not improve from 0.99296
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 13s 845ms/step - accuracy: 0.9941 - loss: 0.0288 - val_accuracy: 0.9859 - val_loss: 0.0438 - learning_rate: 0.0010
# Epoch 15/15
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 638ms/step - accuracy: 0.9985 - loss: 0.0204
# Epoch 15: val_accuracy did not improve from 0.99296
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 13s 832ms/step - accuracy: 0.9941 - loss: 0.0302 - val_accuracy: 0.9930 - val_loss: 0.0342 - learning_rate: 0.0010

# %%
# 5. TRAINING PLOTS
def plot_hist(hist):
    plt.figure(figsize=(12, 4))

    plt.subplot(1, 2, 1)
    plt.plot(hist.history['accuracy'], label='Training Accuracy')
    plt.plot(hist.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Model Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(hist.history['loss'], label='Training Loss')
    plt.plot(hist.history['val_loss'], label='Validation Loss')
    plt.title('Model Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout()
    plt.show()

plot_hist(history)

# %%
# 6. FINE-TUNING
for layer in base_model.layers[-30:]:
    layer.trainable = True

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

history_fine = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=2,
    callbacks=[early_stop, reduce_lr]
)

plot_hist(history_fine)
# Out:
# Epoch 1/2
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.9329 - loss: 0.2043 - val_accuracy: 0.8662 - val_loss: 0.4078 - learning_rate: 1.0000e-04
# Epoch 2/2
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.9862 - loss: 0.0458 - val_accuracy: 0.9577 - val_loss: 0.1410 - learning_rate: 1.0000e-04

# %%
# 7. EVALUATE ON TEST SET
resnet_dir = os.path.join('Models', 'ResNet50')
model_path = os.path.join(resnet_dir, 'resnet50_model.keras')

if os.path.exists(model_path):
    eval_model = tf.keras.models.load_model(model_path)
else:
    eval_model = model

test_loss, test_acc = eval_model.evaluate(test_gen)
print("TEST ACCURACY:", test_acc)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 459ms/step - accuracy: 0.8780 - loss: 0.3587
# TEST ACCURACY: 0.8780487775802612

# %%
# 8. SAVE MODEL
os.makedirs(resnet_dir, exist_ok=True)
model.save(os.path.join(resnet_dir, 'resnet50_model.keras'))
print("Model saved as .keras file!")
# Out:
# Model saved as .keras file!

# %%
# 9. LOAD MODEL
from tensorflow import keras

loaded_model = keras.models.load_model('Models/ResNet50/resnet50_model.keras')

print("Model loaded successfully!")
# Out:
# Model loaded successfully!
